# %% [markdown]
# ODR Sequential Serial Bias
# ==========================

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Notebook Settings

# %% [markdown]
#     The autoreload extension is already loaded. To reload it, use:
#       %reload_ext autoreload
#     Python exe
#     /home/leon/mambaforge/envs/torch/bin/python

# %% [markdown]
# ## Helpers

# %% [markdown]
# ## Model

# %% [markdown]
#     seed 1
#
#     1050
#     450
#
# ![img](./figures/odr_seq_sb/figure_16.png)

# %% [markdown]
# ## Simulating Consecutive Trials

# %% [markdown]
#     torch.Size([10, 710, 1500]) torch.Size([10, 61, 1050])
#
#     100% 50/50 [03:38<00:00,  4.38s/it]rates (50, 10, 61, 1050)
#     curr (50, 10, 1) prev (50, 10, 1) iti (500,)
#
#     (2, 10) (2, 10)
#
#     (50, 10, 61)
#
#     4.894893836975095
#
# ![img](./figures/odr_seq_sb/figure_24.png)
#
# ![img](./figures/odr_seq_sb/figure_25.png)
#
#     saving to ./models/nih//rates_list_controls.pkl
#     saving to ./models/nih//curr_list_controls.pkl
#     saving to ./models/nih//prev_list_controls.pkl
#     saving to ./models/nih//iti_list_controls.pkl
#     saving to ./models/nih//start_idx_controls.pkl
#     saving to ./models/nih//end_idx_controls.pkl
#     saving to ./models/nih//phi_list_controls.pkl
#
# ![img](./figures/odr_seq_sb/figure_27.png)

# %% [markdown]
# ## Errors

# %% [markdown]
#     25
#
#     (25, 10, 1) (25, 10, 1)
#
#     phi (25, 10, 61) prev (25, 10, 1)
#
#     targ (250, 1) rel (250, 1) errors (25, 10, 61) idx start_idx (2, 10)
#
#     (250, 1) (250, 1)
#
# ![img](./figures/odr_seq_sb/figure_39.png)
#
# ![img](./figures/odr_seq_sb/figure_40.png)

# %% [markdown]
# ## Biases

# %% [markdown]
#     (250, 1) (250, 1) (250, 1)
#
# ![img](./figures/odr_seq_sb/figure_46.png)

# %% [markdown]
# ## Delay Dependency

# %% [markdown]
# ![img](./figures/odr_seq_sb/figure_49.png)
#
# ![img](./figures/odr_seq_sb/figure_50.png)
#
# ![img](./figures/odr_seq_sb/figure_52.png)

# %% [markdown]
# ## History Effects

# %% [markdown]
#     19292ba6-def9-4b47-b36f-a42c192d787b
#
#     6aff6f49-4e5e-4e69-bd78-4ff4a3a5d65b

# %% [markdown]
# ## Trial Dependency

# %% [markdown]
# ![img](./figures/odr_seq_sb/figure_53.png)

# %% [markdown]
# ## ITI Dependency

# %% [markdown]
#     [1.] 7680
#
# ![img](./figures/odr_seq_sb/figure_53.png)
