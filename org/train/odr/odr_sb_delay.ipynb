# %% [markdown]
# ODR serial bias
# ===============

# %% [markdown]
# ## Notebook Settings

# %% [markdown]
#     The autoreload extension is already loaded. To reload it, use:
#       %reload_ext autoreload
#     Python exe
#     /home/leon/mambaforge/envs/torch/bin/python

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Helpers

# %% [markdown]
# ## Model

# %% [markdown]
#     seed 1

# %% [markdown]
# ## Batching Inputs

# %% [markdown]
#     512
#     torch.Size([1, 750]) torch.Size([512, 1])
#     torch.Size([1, 750]) torch.Size([512, 1])
#     torch.Size([1, 750]) torch.Size([512, 1])
#     torch.Size([1, 750]) torch.Size([512, 1])
#
#     torch.Size([4, 512])
#
#     rates (512, 151, 750)

# %% [markdown]
# ## Results

# %% [markdown]
# ### Rates

# %% [markdown]
# ![img](./figures/odr_sb/figure_18.png)
#
#     (512, 4, 1)
#     132.0
#     110.77687954785429

# %% [markdown]
# ### errors

# %% [markdown]
#     (2, 512, 151) (512, 1) (512, 1)
#
# ![img](./figures/odr_sb/figure_21.png)
#
#     (512, 151) (512, 4, 1) torch.Size([4, 512])
#     [8.9       7.7799997 6.48      7.3599997 6.2599998] [1.0, 5.0, 7.0, 11.0]
#     [88 76 63 72 61]
#
# ![img](./figures/odr_sb/figure_23.png)
#
#     (2, 512)
#
# ![img](./figures/odr_sb/figure_25.png)

# %% [markdown]
# ### biases

# %% [markdown]
# ![img](./figures/odr_sb/figure_28.png)
#
# ![img](./figures/odr_sb/figure_30.png)
